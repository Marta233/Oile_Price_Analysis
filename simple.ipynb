# %%
import pandas as pd

# %%
Data = pd.read_csv('./Data/Copy of BrentOilPrices.csv')

# %%
Data
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 9006  Nov 08, 2022  96.85
# 9007  Nov 09, 2022  93.05
# 9008  Nov 10, 2022  94.25
# 9009  Nov 11, 2022  96.37
# 9010  Nov 14, 2022  93.59
#
# [9011 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# %%
# Ensure the date column is in datetime format
Data['Date'] = pd.to_datetime(Data['Date'])
Data.set_index('Date', inplace=True)
# Out:
# C:\Users\marta\AppData\Local\Temp\ipykernel_9184\2076066624.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Data['Date'] = pd.to_datetime(Data['Date'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(Data['Price'])
plt.title('Brent Oil Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
